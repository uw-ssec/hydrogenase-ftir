# %%
from jcamp import jcamp_readfile
import matplotlib.pyplot as plt

# %%
#importing the water vapor spectrum from this link: `https://webbook.nist.gov/cgi/inchi?ID=C7732185&Type=IR-SPEC&Index=0#IR-SPEC`

wv_spectra = jcamp_readfile('7732-18-5-IR.jdx')

# %%
len(wv_spectra['y'])
# Out:
# 880

# %%
print(wv_spectra['maxy'])
# Out:
# 0.62833

# %%
plt.plot(wv_spectra['x'], wv_spectra['y'])
